# %%
import music21

# %%
kingdom = "Kingdom_Hearts_Dearly_Beloved.mid"

# %%
DATA_PATH = "midi_songs/"

# %%
f = note.Note("F5")

# %%
f
# Out:
# <music21.note.Note F>

# %%
print(pitch.Pitch("B").french)
# Out:
# si

# %%
midifile = music21.midi.MidiFile.open(filename="midi_songs/Kingdom_Hearts_Dearly_Beloved.mid")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7204065a2de1> in <module>()
# ----> 1 midifile = music21.midi.MidiFile.open(filename="midi_songs/Kingdom_Hearts_Dearly_Beloved.mid")
#
# TypeError: open() missing 1 required positional argument: 'self'

# %%
from music21 import converter,instrument # or import *
file = converter.parse("midi_songs/Kingdom_Hearts_Dearly_Beloved.mid")
components = []
for element in file.recurse():
    components.append(element)

# %%
components
# Out:
# [<music21.stream.Score 0x24a29afa470>,
#  <music21.stream.Part 0x24a29afa5f8>,
#  <music21.instrument.Piano Piano>,
#  <music21.key.Key of E- major>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Rest rest>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Rest rest>,
#  <music21.note.Note D>,
#  <music21.note.Note E->,
#  <music21.note.Rest rest>,
#  <music21.note.Note E->,
# ...

# %%
sp = music21.midi.realtime.StreamPlayer(file)

# %%
sp.play()
